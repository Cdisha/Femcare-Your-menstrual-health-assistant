# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\cdish\miniconda3\lib\site-packages (0.8.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (2.161.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: pydantic in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\cdish\miniconda3\lib\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\cdish\miniconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-core->google-generativeai) (1.68.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\cdish\miniconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cdish\miniconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cdish\miniconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\cdish\miniconda3\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\cdish\miniconda3\lib\site-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\cdish\miniconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\cdish\miniconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\cdish\miniconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\cdish\miniconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cdish\miniconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cdish\miniconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cdish\miniconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cdish\miniconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.2.2)

# %%
pip install mistralai
# Out:
# Requirement already satisfied: mistralai in c:\users\cdish\miniconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\users\cdish\miniconda3\lib\site-packages (from mistralai) (0.2.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\cdish\miniconda3\lib\site-packages (from mistralai) (0.28.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\cdish\miniconda3\lib\site-packages (from mistralai) (1.0.6)
# Requirement already satisfied: pydantic>=2.9.0 in c:\users\cdish\miniconda3\lib\site-packages (from mistralai) (2.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cdish\miniconda3\lib\site-packages (from mistralai) (2.8.2)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\cdish\miniconda3\lib\site-packages (from mistralai) (0.9.0)
# Requirement already satisfied: anyio in c:\users\cdish\miniconda3\lib\site-packages (from httpx>=0.27.0->mistralai) (4.8.0)
# Requirement already satisfied: certifi in c:\users\cdish\miniconda3\lib\site-packages (from httpx>=0.27.0->mistralai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\cdish\miniconda3\lib\site-packages (from httpx>=0.27.0->mistralai) (1.0.7)
# Requirement already satisfied: idna in c:\users\cdish\miniconda3\lib\site-packages (from httpx>=0.27.0->mistralai) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\cdish\miniconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->mistralai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\cdish\miniconda3\lib\site-packages (from pydantic>=2.9.0->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\cdish\miniconda3\lib\site-packages (from pydantic>=2.9.0->mistralai) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\cdish\miniconda3\lib\site-packages (from pydantic>=2.9.0->mistralai) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\cdish\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->mistralai) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\cdish\miniconda3\lib\site-packages (from typing-inspect>=0.9.0->mistralai) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cdish\miniconda3\lib\site-packages (from anyio->httpx>=0.27.0->mistralai) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mistralai.client import MistralClient

# %%
"""import google.generativeai as genai
import json
from datetime import datetime
import os
import requests

# Set up Gemini API key
api_key = os.getenv("GEMINI_API_KEY", "AIzaSyCLnI_Tl1zS3nRcfBWsyBhxiJvu3x9dOLw")

# Set up Mistral API key
mistral_api_key = os.getenv("MISTRAL_API_KEY", "J2hdJ9IT34rK8P0t6SnJQkLfpCUTA9vy")

# Configure Gemini
genai.configure(api_key=api_key)

# Load user data (simulating a database)
USER_DATA_FILE = "user_data.json"

# Define prompt templates
PROMPT_TEMPLATES = {
    "general_health": (
        "You are a menstrual health assistant. Provide a clear, factual, and educational response to the following question about menstrual health: {user_input}. "
        "Ensure the response is appropriate for all audiences and avoids harmful or sensitive language."
    ),
    "nutrition": (
        "You are a nutritionist specializing in menstrual health. Based on the user's current cycle phase ({cycle_phase}) and cravings ({cravings}), "
        "provide specific dietary recommendations that align with their cravings and cycle phase. For example, if they crave spicy food, suggest spicy and healthy options. "
        "Answer the following question: {user_input}"
    ),
    "child_friendly": (
    "You are a friendly menstrual health assistant, explaining menstrual health topics in a clear, simple, and age-appropriate way. "
    "Answer the question: '{user_input}' directly, without discussing unrelated topics. "
    "Use comforting and inclusive language, keep the response brief and factual, and avoid overwhelming details. "
    "Provide reassurance if the question involves symptoms like cramps, mood swings, or discharge, but do not mention additional symptoms unless asked."
    ),
 
    "exercise": (
    "You are a fitness coach specializing in menstrual health. Based on the user's cycle phase ({cycle_phase}) and energy levels, "
    "recommend specific exercises suited to that phase. Provide clear workout suggestions with phase-specific titles such as '**Exercises for the {cycle_phase} Phase**' "
    "and include options for different energy levels. Keep the tone encouraging and supportive while focusing on menstrual health benefits. "
    "Answer the following question: '{user_input}'"
    ),

    "cravings_alternatives": (
    "You are a nutritionist focused on menstrual health. Suggest specific, healthy, and satisfying alternatives tailored to the user's cravings ({cravings}) "
    "and current cycle phase ({cycle_phase}). Provide clear options under a phase-specific title like '**Healthy Alternatives for {cravings} Cravings in the {cycle_phase} Phase**' "
    "and offer a variety of sweet, salty, or spicy alternatives as relevant. Keep the tone encouraging and practical. "
    "Answer the following question: '{user_input}'"
    ),

    "meal_planner": (
        "You are a nutritionist specializing in menstrual health. Create a detailed daily meal plan with breakfast, lunch, and dinner, considering the user's cycle phase ({cycle_phase}), "
        "cravings ({cravings}), dietary specifications ({dietary_specs}), preferred cuisine ({cuisine}), and allergies ({allergies}). "
        "Ensure the meals are nutritious, satisfying, and help manage common menstrual symptoms. Provide the plan in the following format:\n"
        "**Breakfast:** [meal]\n**Lunch:** [meal]\n**Dinner:** [meal]"
    ),
    
    "fertility": (
    "You are a menstrual health assistant specializing in fertility, ovulation, and menstrual cycles. "
    "Answer the question: '{user_input}' directly, without adding unrelated information. "
    "Explain fertility concepts clearly, including ovulation signs, fertility windows, and conception tips if relevant. "
    "Maintain a supportive tone, avoid jargon, and only mention additional symptoms or fertility challenges if specifically asked."

    ),
    
    "puberty": (
    "You are a menstrual health assistant helping individuals understand puberty, periods, and menstrual health. "
    "Answer the question: '{user_input}' directly, without discussing unrelated topics. "
    "Use clear, factual, and empathetic language, and explain biological processes simply. "
    "If the question involves symptoms like cramps or mood swings, provide practical tips, but do not mention other symptoms unless asked."
    )  
    
}
    


def load_user_data():
    try:
        with open(USER_DATA_FILE, "r") as file:
            return json.load(file)
    except FileNotFoundError:
        return {}

def save_user_data(data):
    with open(USER_DATA_FILE, "w") as file:
        json.dump(data, file, indent=4)

def ask_mistral(prompt):
    url = "https://api.mistral.ai/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {mistral_api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "model": "mistral-large-latest",
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": 300
    }
    try:
        response = requests.post(url, headers=headers, json=payload)
        response_data = response.json()
        return response_data.get("choices", [{}])[0].get("message", {}).get("content", "Error: Unable to fetch response from Mistral.").strip()
    except Exception as e:
        return f"Error: {str(e)}"

def ask_gpt(prompt):
    try:
        model = genai.GenerativeModel('gemini-1.5-pro-latest')
        response = model.generate_content(prompt)
        
        # Check if the response was blocked due to safety concerns
        if response.candidates and response.candidates[0].finish_reason == 3:
            print("Gemini blocked the response due to safety concerns. Falling back to Mistral.")
            return "FALLBACK_TO_MISTRAL"
        
        # Return the response if it's valid
        if response.text:
            return response.text.strip()
        else:
            return "FALLBACK_TO_MISTRAL"
    except Exception as e:
        print(f"Gemini Error: {str(e)}")
        return "FALLBACK_TO_MISTRAL"


def determine_intent(user_input, age, cravings):
    user_input = user_input.lower()
    if age < 18:
        return "child_friendly"
    elif "alternative" in user_input and cravings:  # Prioritize cravings_alternatives
        return "cravings_alternatives"
    elif any(word in user_input for word in ["nutrition", "diet", "food", "eat"]):
        return "nutrition"
    elif any(word in user_input for word in ["exercise", "workout", "fitness"]):
        return "exercise"
    elif any(word in user_input for word in ["pregnant", "fertility", "ovulation", "get pregnant"]):
        return "fertility"
    elif any(word in user_input for word in ["puberty", "11 years old", "teen", "young"]):
        return "puberty"
    else:
        return "general_health"
def ask_quiz():
    print("\nLet's do a quick menstrual health quiz!")
    score = 0
    questions = [
        ("How long is an average menstrual cycle? (a) 21 days (b) 28 days (c) 35 days", "b"),
        ("Which phase comes after ovulation? (a) Follicular (b) Luteal (c) Menstrual", "b"),
        ("Is it normal to experience mood swings during your cycle? (yes/no)", "yes")
    ]

    for question, correct_answer in questions:
        answer = input(question + "\nYour answer: ").strip().lower()
        if answer == correct_answer:
            score += 1

    print(f"\nYour score: {score}/{len(questions)}")
    print("Great job! Keep learning about your health.")

def ask_meal_planner(user_data, user_id):
    print("\nMeal Planner")
    user_data[user_id]["dietary_specs"] = input("Do you have any dietary specifications? (e.g., vegetarian, vegan, gluten-free, none): ")
    user_data[user_id]["cuisine"] = input("What type of cuisine do you prefer? (e.g., Italian, Indian, Mediterranean, no preference): ")
    user_data[user_id]["allergies"] = input("Do you have any food allergies? (If none, type 'none'): ")
    save_user_data(user_data)

    meal_prompt = PROMPT_TEMPLATES["meal_planner"].format(
        cycle_phase=user_data[user_id]["cycle_phase"],
        cravings=user_data[user_id]["cravings"],
        dietary_specs=user_data[user_id]["dietary_specs"],
        cuisine=user_data[user_id]["cuisine"],
        allergies=user_data[user_id]["allergies"]
    )
    meal_plan = ask_gpt(meal_prompt)
    print("\nMeal Plan:\n" + meal_plan)
    
def chatbot(user_id):
    user_data = load_user_data()

    # Always prompt for user details
    if user_id not in user_data or True:
        user_data[user_id] = {
            "name": input("What is your name? "),
            "age": int(input("How old are you? ")),
            "cycle_phase": input("What is your current menstrual cycle phase? (e.g., follicular, ovulatory, luteal, menstrual): "),
            "cravings": input("What are you craving today? (e.g., sweet, salty, chocolate, spicy, etc.): "),
            "dietary_specs": None,
            "cuisine": None,
            "allergies": None,
            "last_interaction": datetime.now().isoformat(),
        }
        save_user_data(user_data)

    print("\nWelcome to the Menstrual Health Chatbot!")
    print("Categories: General Health, Nutrition, Child-Friendly, Exercise, Cravings Alternatives")

    while True:
        user_input = input("\nWhat would you like to ask? (Type 'exit' to quit): ")

        if user_input.lower() == "exit":
            print("Goodbye! Take care of your health.")
            break

        age = user_data[user_id]["age"]
        cravings = user_data[user_id]["cravings"]
        cycle_phase = user_data[user_id]["cycle_phase"]
        intent = determine_intent(user_input, age, cravings)

        if intent == "nutrition":
            prompt = PROMPT_TEMPLATES["nutrition"].format(cycle_phase=cycle_phase, cravings=cravings, user_input=user_input)
        elif intent == "child_friendly":
            prompt = PROMPT_TEMPLATES["child_friendly"].format(user_input=user_input)
        elif intent == "exercise":
            prompt = PROMPT_TEMPLATES["exercise"].format(cycle_phase=cycle_phase, user_input=user_input)
        elif intent == "cravings_alternatives":
            prompt = PROMPT_TEMPLATES["cravings_alternatives"].format(cravings=cravings, cycle_phase=cycle_phase, user_input=user_input)
        elif intent == "fertility":
            prompt = PROMPT_TEMPLATES["fertility"].format(user_input=user_input)
        elif intent == "puberty":
            prompt = PROMPT_TEMPLATES["puberty"].format(user_input=user_input)
        else:
            prompt = PROMPT_TEMPLATES["general_health"].format(user_input=user_input)

        # Try Gemini first
        response = ask_gpt(prompt)
        
        # Fallback to Mistral if Gemini flags the question or fails
        if response == "FALLBACK_TO_MISTRAL":
            print("Switching to Mistral for this question...")
            response = ask_mistral(prompt)
        
        print(f"\nChatbot: {response}")

    # After exiting, ask for quiz and meal planner
    if input("\nWould you like to take a quick menstrual health quiz? (yes/no): ").lower() == "yes":
        ask_quiz()

    if input("\nWould you like to use the meal planner? (yes/no): ").lower() == "yes":
        ask_meal_planner(user_data, user_id)


if __name__ == "__main__":
    user_id = input("Enter your user ID (e.g., your name or email): ")
    chatbot(user_id)  # Now this function is correctly defined at the global level"""
# Out:
# 'import google.generativeai as genai\nimport json\nfrom datetime import datetime\nimport os\nimport requests\n\n# Set up Gemini API key\napi_key = os.getenv("GEMINI_API_KEY", "AIzaSyCLnI_Tl1zS3nRcfBWsyBhxiJvu3x9dOLw")\n\n# Set up Mistral API key\nmistral_api_key = os.getenv("MISTRAL_API_KEY", "J2hdJ9IT34rK8P0t6SnJQkLfpCUTA9vy")\n\n# Configure Gemini\ngenai.configure(api_key=api_key)\n\n# Load user data (simulating a database)\nUSER_DATA_FILE = "user_data.json"\n\n# Define prompt templates\nPROMPT_TEMPLATES = {\n    "general_health": (\n        "You are a menstrual health assistant. Provide a clear, factual, and educational response to the following question about menstrual health: {user_input}. "\n        "Ensure the response is appropriate for all audiences and avoids harmful or sensitive language."\n    ),\n    "nutrition": (\n        "You are a nutritionist specializing in menstrual health. Based on the user\'s current cycle phase ({cycle_phase}) and cravings ({cravings}), "\n        "provide specific dietary recommendations that align with their cravings and cycle phase. For example, if they crave spicy food, suggest spicy and healthy options. "\n        "Answer the following question: {user_input}"\n    ),\n    "child_friendly": (\n    "You are a friendly menstrual health assistant, explaining menstrual health topics in a clear, simple, and age-appropriate way. "\n    "Answer the question: \'{user_input}\' directly, without discussing unrelated topics. "\n    "Use comforting and inclusive language, keep the response brief and factual, and avoid overwhelming details. "\n    "Provide reassurance if the question involves symptoms like cramps, mood swings, or discharge, but do not mention additional symptoms unless asked."\n    ),\n \n    "exercise": (\n    "You are a fitness coach specializing in menstrual health. Based on the user\'s cycle phase ({cycle_phase}) and energy levels, "\n    "recommend specific exercises suited to that phase. Provide clear workout suggestions with phase-specific titles such as \'**Exercises for the {cycle_phase} Phase**\' "\n    "and include options for different energy levels. Keep the tone encouraging and supportive while focusing on menstrual health benefits. "\n    "Answer the following question: \'{user_input}\'"\n    ),\n\n    "cravings_alternatives": (\n    "You are a nutritionist focused on menstrual health. Suggest specific, healthy, and satisfying alternatives tailored to the user\'s cravings ({cravings}) "\n    "and current cycle phase ({cycle_phase}). Provide clear options under a phase-specific title like \'**Healthy Alternatives for {cravings} Cravings in the {cycle_phase} Phase**\' "\n    "and offer a variety of sweet, salty, or spicy alternatives as relevant. Keep the tone encouraging and practical. "\n    "Answer the following question: \'{user_input}\'"\n    ),\n\n    "meal_planner": (\n        "You are a nutritionist specializing in menstrual health. Create a detailed daily meal plan with breakfast, lunch, and dinner, considering the user\'s cycle phase ({cycle_phase}), "\n        "cravings ({cravings}), dietary specifications ({dietary_specs}), preferred cuisine ({cuisine}), and allergies ({allergies}). "\n        "Ensure the meals are nutritious, satisfying, and help manage common menstrual symptoms. Provide the plan in the following format:\n"\n        "**Breakfast:** [meal]\n**Lunch:** [meal]\n**Dinner:** [meal]"\n    ),\n    \n    "fertility": (\n    "You are a menstrual health assistant specializing in fertility, ovulation, and menstrual cycles. "\n    "Answer the question: \'{user_input}\' directly, without adding unrelated information. "\n    "Explain fertility concepts clearly, including ovulation signs, fertility windows, and conception tips if relevant. "\n    "Maintain a supportive tone, avoid jargon, and only mention additional symptoms or fertility challenges if specifically asked."\n\n    ),\n    \n    "puberty": (\n    "You are a menstrual health assistant help ...

# %%
import google.generativeai as genai
import json
from datetime import datetime
import os
import requests
import time

# Set up Gemini API key
api_key = os.getenv("GEMINI_API_KEY", "AIzaSyCLnI_Tl1zS3nRcfBWsyBhxiJvu3x9dOLw")

# Set up Mistral API key
mistral_api_key = os.getenv("MISTRAL_API_KEY", "J2hdJ9IT34rK8P0t6SnJQkLfpCUTA9vy")

# Configure Gemini
genai.configure(api_key=api_key)

# Load user data (simulating a database)
USER_DATA_FILE = "user_data.json"

# Define prompt templates
PROMPT_TEMPLATES = {
    "general_health": (
        "You are a menstrual health assistant. Provide a clear, factual, and educational response to the following question about menstrual health: {user_input}. "
        "Ensure the response is appropriate for all audiences and avoids harmful or sensitive language."
    ),
    "nutrition": (
        "You are a nutritionist specializing in menstrual health. Based on the user's current cycle phase ({cycle_phase}) and cravings ({cravings}), "
        "provide specific dietary recommendations that align with their cravings and cycle phase. For example, if they crave spicy food, suggest spicy and healthy options. "
        "Answer the following question: {user_input}"
    ),
    "child_friendly": (
        "You are a friendly menstrual health assistant, explaining menstrual health topics in a clear, simple, and age-appropriate way. "
        "Answer the question: '{user_input}' directly, without discussing unrelated topics. "
        "Use comforting and inclusive language, keep the response brief and factual, and avoid overwhelming details. "
        "Provide reassurance if the question involves symptoms like cramps, mood swings, or discharge, but do not mention additional symptoms unless asked."
    ),
    "exercise": (
        "You are a fitness coach specializing in menstrual health. Based on the user's cycle phase ({cycle_phase}) and energy levels, "
        "recommend specific exercises suited to that phase. Provide clear workout suggestions with phase-specific titles such as '**Exercises for the {cycle_phase} Phase**' "
        "and include options for different energy levels. Keep the tone encouraging and supportive while focusing on menstrual health benefits. "
        "Answer the following question: '{user_input}'"
    ),
    "cravings_alternatives": (
        "You are a nutritionist focused on menstrual health. Suggest specific, healthy, and satisfying alternatives tailored to the user's cravings ({cravings}) "
        "and current cycle phase ({cycle_phase}). Provide clear options under a phase-specific title like '**Healthy Alternatives for {cravings} Cravings in the {cycle_phase} Phase**' "
        "and offer a variety of sweet, salty, or spicy alternatives as relevant. Keep the tone encouraging and practical. "
        "Answer the following question: '{user_input}'"
    ),
    "meal_planner": (
        "You are a nutritionist specializing in menstrual health. Create a detailed daily meal plan with breakfast, lunch, and dinner, considering the user's cycle phase ({cycle_phase}), "
        "cravings ({cravings}), dietary specifications ({dietary_specs}), preferred cuisine ({cuisine}), and allergies ({allergies}). "
        "Ensure the meals are nutritious, satisfying, and help manage common menstrual symptoms. Provide the plan in the following format:\n"
        "**Breakfast:** [meal]\n**Lunch:** [meal]\n**Dinner:** [meal]"
    ),
    "fertility": (
        "You are a menstrual health assistant specializing in fertility, ovulation, and menstrual cycles. "
        "Answer the question: '{user_input}' directly, without adding unrelated information. "
        "Explain fertility concepts clearly, including ovulation signs, fertility windows, and conception tips if relevant. "
        "Maintain a supportive tone, avoid jargon, and only mention additional symptoms or fertility challenges if specifically asked."
    ),
    "puberty": (
        "You are a menstrual health assistant helping individuals understand puberty, periods, and menstrual health. "
        "Answer the question: '{user_input}' directly, without discussing unrelated topics. "
        "Use clear, factual, and empathetic language, and explain biological processes simply. "
        "If the question involves symptoms like cramps or mood swings, provide practical tips, but do not mention other symptoms unless asked."
    )
}

def load_user_data():
    try:
        with open(USER_DATA_FILE, "r") as file:
            return json.load(file)
    except FileNotFoundError:
        return {}

def save_user_data(data):
    with open(USER_DATA_FILE, "w") as file:
        json.dump(data, file, indent=4)

def ask_mistral(prompt):
    url = "https://api.mistral.ai/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {mistral_api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "model": "mistral-large-latest",
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": 300
    }
    try:
        response = requests.post(url, headers=headers, json=payload)
        response_data = response.json()
        return response_data.get("choices", [{}])[0].get("message", {}).get("content", "Error: Unable to fetch response from Mistral.").strip()
    except Exception as e:
        return f"Error: {str(e)}"

def ask_gpt(prompt):
    try:
        # Reinitialize the Gemini model for each question
        model = genai.GenerativeModel('gemini-1.5-pro-latest')
        response = model.generate_content(prompt)
        
        # Check if the response was blocked due to safety concerns
        if response.candidates and response.candidates[0].finish_reason == 3:
            return "FALLBACK_TO_MISTRAL"
        
        # Return the response if it's valid
        if response.text:
            return response.text.strip()
        else:
            return "FALLBACK_TO_MISTRAL"
    except Exception as e:
        return "FALLBACK_TO_MISTRAL"
    finally:
        # Add a small delay to avoid rate limits
        time.sleep(1)

def determine_intent(user_input, age, cravings):
    user_input = user_input.lower()
    if age < 18:
        return "child_friendly"
    elif "alternative" in user_input and cravings:
        return "cravings_alternatives"
    elif any(word in user_input for word in ["nutrition", "diet", "food", "eat"]):
        return "nutrition"
    elif any(word in user_input for word in ["exercise", "workout", "fitness"]):
        return "exercise"
    elif any(word in user_input for word in ["pregnant", "fertility", "ovulation", "get pregnant"]):
        return "fertility"
    elif any(word in user_input for word in ["puberty", "11 years old", "teen", "young"]):
        return "puberty"
    else:
        return "general_health"

def ask_quiz():
    print("\nLet's do a quick menstrual health quiz!")
    score = 0
    questions = [
        ("How long is an average menstrual cycle? (a) 21 days (b) 28 days (c) 35 days", "b"),
        ("Which phase comes after ovulation? (a) Follicular (b) Luteal (c) Menstrual", "b"),
        ("Is it normal to experience mood swings during your cycle? (yes/no)", "yes")
    ]

    for question, correct_answer in questions:
        answer = input(question + "\nYour answer: ").strip().lower()
        if answer == correct_answer:
            score += 1

    print(f"\nYour score: {score}/{len(questions)}")
    print("Great job! Keep learning about your health.")

def ask_meal_planner(user_data, user_id):
    print("\nMeal Planner")
    user_data[user_id]["dietary_specs"] = input("Do you have any dietary specifications? (e.g., vegetarian, vegan, gluten-free, none): ")
    user_data[user_id]["cuisine"] = input("What type of cuisine do you prefer? (e.g., Italian, Indian, Mediterranean, no preference): ")
    user_data[user_id]["allergies"] = input("Do you have any food allergies? (If none, type 'none'): ")
    save_user_data(user_data)

    meal_prompt = PROMPT_TEMPLATES["meal_planner"].format(
        cycle_phase=user_data[user_id]["cycle_phase"],
        cravings=user_data[user_id]["cravings"],
        dietary_specs=user_data[user_id]["dietary_specs"],
        cuisine=user_data[user_id]["cuisine"],
        allergies=user_data[user_id]["allergies"]
    )
    meal_plan = ask_gpt(meal_prompt)
    print("\nMeal Plan:\n" + meal_plan)

def handle_question(user_input, user_data, user_id):
    age = user_data[user_id]["age"]
    cravings = user_data[user_id]["cravings"]
    cycle_phase = user_data[user_id]["cycle_phase"]
    intent = determine_intent(user_input, age, cravings)

    if intent == "nutrition":
        prompt = PROMPT_TEMPLATES["nutrition"].format(cycle_phase=cycle_phase, cravings=cravings, user_input=user_input)
    elif intent == "child_friendly":
        prompt = PROMPT_TEMPLATES["child_friendly"].format(user_input=user_input)
    elif intent == "exercise":
        prompt = PROMPT_TEMPLATES["exercise"].format(cycle_phase=cycle_phase, user_input=user_input)
    elif intent == "cravings_alternatives":
        prompt = PROMPT_TEMPLATES["cravings_alternatives"].format(cravings=cravings, cycle_phase=cycle_phase, user_input=user_input)
    elif intent == "fertility":
        prompt = PROMPT_TEMPLATES["fertility"].format(user_input=user_input)
    elif intent == "puberty":
        prompt = PROMPT_TEMPLATES["puberty"].format(user_input=user_input)
    else:
        prompt = PROMPT_TEMPLATES["general_health"].format(user_input=user_input)

    # Always try Gemini first for each question
    response = ask_gpt(prompt)
    
    # Fallback to Mistral only if Gemini fails for this specific question
    if response == "FALLBACK_TO_MISTRAL":
        response = ask_mistral(prompt)
    
    print(f"\nChatbot: {response}")

def chatbot(user_id):
    user_data = load_user_data()

    # Always prompt for user details
    if user_id not in user_data or True:
        user_data[user_id] = {
            "name": input("What is your name? "),
            "age": int(input("How old are you? ")),
            "cycle_phase": input("What is your current menstrual cycle phase? (e.g., follicular, ovulatory, luteal, menstrual): "),
            "cravings": input("What are you craving today? (e.g., sweet, salty, chocolate, spicy, etc.): "),
            "dietary_specs": None,
            "cuisine": None,
            "allergies": None,
            "last_interaction": datetime.now().isoformat(),
        }
        save_user_data(user_data)

    print("\nWelcome to the Menstrual Health Chatbot!")
    print("Categories: General Health, Nutrition, Child-Friendly, Exercise, Cravings Alternatives")

    while True:
        user_input = input("\nWhat would you like to ask? (Type 'exit' to quit): ")

        if user_input.lower() == "exit":
            print("Goodbye! Take care of your health.")
            break

        # Handle the question
        handle_question(user_input, user_data, user_id)

    # After exiting, ask for quiz and meal planner
    if input("\nWould you like to take a quick menstrual health quiz? (yes/no): ").lower() == "yes":
        ask_quiz()

    if input("\nWould you like to use the meal planner? (yes/no): ").lower() == "yes":
        ask_meal_planner(user_data, user_id)

if __name__ == "__main__":
    user_id = input("Enter your user ID (e.g., your name or email): ")
    chatbot(user_id)
# Out:
# Welcome to the Menstrual Health Chatbot!
# Categories: General Health, Nutrition, Child-Friendly, Exercise, Cravings Alternatives
#
# Chatbot: Periods, also known as menstruation, are a normal and healthy part of life for most women and people assigned female at birth.  They are a sign that the reproductive system is working.  Here's a breakdown:
#
# * **What happens:**  Each month, the body prepares for a potential pregnancy. The lining of the uterus (womb) thickens with blood and nutrients to nourish a fertilized egg. If pregnancy doesn't occur, the lining sheds, and this is what we experience as a period.  The blood and tissue leave the body through the vagina.
#
# * **The cycle:** The menstrual cycle is counted from the first day of one period to the first day of the next.  While the average cycle is about 28 days, it can range from 21 to 35 days and still be considered normal.  Cycles can also vary in length from one month to the next, especially during puberty and perimenopause.
#
# * **Typical duration:** Bleeding typically lasts from 2 to 7 days.
#
# * **Common experiences:**  Along with bleeding, some people experience other symptoms like:
#     * **Cramps:**  Painful muscle contractions in the lower abdomen or back.
#     * **Bloating:**  A feeling of fullness or tightness in the abdomen.
#     * **Mood changes:**  Feeling more emotional or irritable.
#     * **Breast tenderness:**  Breasts may feel sore or swollen.
#     * **Headaches:**
#     * **Fatigue:**
#
# * **Managing periods:**  There are several ways to manage menstrual bleeding:
#     * **Sanitary pads:**  Absorbent pads worn inside underwear.
#     * **Tampons:** Absorbent inserts placed inside the vagina.
#     * **Menstrual cups:** Flexible cups inserted into the vagina to collect blood.
#     * **Menstrual discs:**  Similar to cups, but flatter and placed differently.
#     * **Period underwear:**  Reusable underwear designed to absorb menstrual blood.
#
# * **When to seek medical advice:**  While variations in cycle length and flow are normal, it's important to talk to a doctor if you experience:
#     * Very heavy bleeding (soaking through a pad or tampon every hour).
#     * Periods that last longer than 7 days.
#     * Severe pain.
#     * Periods that stop suddenly (other than during pregnancy or menopause).
#     * Bleeding between periods.
#
#
# It's important to remember that everyone's experience with menstruation is unique. If you have any concerns or questions about your period, talking to a healthcare professional or a trusted adult is always a good idea.
#
# Chatbot: You are most likely to get pregnant during the **ovulatory phase** of your menstrual cycle.
#
# Ovulation is when a mature egg is released from the ovary, travels down the fallopian tube, and is available to be fertilized by sperm.  This typically happens about 14 days before the start of your next period, but can vary from person to person and cycle to cycle.  The days just before and after ovulation are the most fertile, as sperm can survive in the reproductive tract for several days.
#
# It's important to understand that while the ovulatory phase is when pregnancy is *most* likely, pregnancy is possible at other times during the cycle as well.  If you are having unprotected sex and do not wish to become pregnant, using reliable contraception is crucial throughout your entire menstrual cycle.
#
# Chatbot: It's great that you're tuning into your body's needs during your cycle! Cravings are normal, and during the ovulatory phase, your body is typically energized.  Let's find some healthy swaps for those momo cravings that still provide satisfaction while supporting your hormonal balance.
#
# **Healthy Alternatives for Momo Cravings in the Ovulatory Phase**
#
# The ovulatory phase is a time of high energy and generally stable blood sugar, making it a good time to experiment with different flavors and textures.
#
# **Savory & Similar Texture:**
#
# * **Shrimp & Veggie Potstickers (Steamed, not fried):** Opt for whole wheat or gluten-free wrappers and load them up with shrimp, shredded cabbage, carrots, and shiitake mushrooms. Steaming preserves nutrients and provides a similar texture to momos.  A dipping sauce made with tamari, rice vinegar, ginger, and a touch of chili garlic sauce can mimic the spicy kick you might be craving.
#
# * **Chicken & Spinach-Stuffed Mushrooms:** Large portobello mushroom caps can act as edible bowls filled with a flavorful mixture of ground chicken, spinach, garlic, and ginger. Baking or grilling these creates a satisfying, umami-rich alternative.
#
# * **Lentil & Vegetable "Meatballs" with Zucchini Noodles:**  These provide a plant-based, high-protein option. Serve the "meatballs" (made with lentils, grated veggies, and herbs) over zucchini noodles tossed with a light pesto or a tahini-based sauce for a balanced and nutritious meal.
#
# **Addressing Specific Craving Elements:**
#
# * **If you crave the doughy texture:** Try a small portion of whole-wheat dumplings filled with lean protein and veggies.  Alternatively, experiment with cauliflower "rice" as a base for a stir-fry with similar flavors to your favorite momo filling.
#
# * **If you crave the spicy kick:** Add a dash of cayenne pepper or a spoonful of your favorite chili paste to your meals.  Ginger and garlic also add warming spice and support digestion.
#
# * **If you crave the savory filling:** Experiment with different protein sources like ground turkey, chicken, or tofu.  Combine them with finely chopped vegetables and aromatic spices to create a delicious and satisfying filling for lettuce wraps, bell peppers, or baked sweet potatoes.
#
#
# **Sweet Alternatives (if you're experiencing sweet cravings too):**
#
# * **Berries with Greek Yogurt & a sprinkle of cinnamon:** This combination offers a refreshing and satisfying sweetness with the added benefit of protein and antioxidants.
#
# * **Baked Apple with chopped walnuts and a drizzle of honey:** This warm and comforting dessert is naturally sweet and provides fiber and healthy fats.
#
# Remember to listen to your body.  These are just suggestions, so feel free to adapt them to your own preferences and dietary needs.  Enjoy exploring these delicious and healthy alternatives to your cravings!
#
# Chatbot: Both tampons and pads are safe menstrual products when used correctly.  Neither is inherently "healthier" than the other – it comes down to personal preference, comfort, and individual needs.
#
# **Tampons:**
#
# * **Safety:** Tampons are safe when used as directed.  Change your tampon every 4-8 hours to minimize the risk of Toxic Shock Syndrome (TSS), a rare but serious bacterial infection.  Always use the lowest absorbency necessary for your flow.
# * **Pros:** Tampons allow you to swim, participate in sports, and wear tighter clothing without worrying about leaks. They can be more discreet and convenient for some.
# * **Cons:**  Some people find insertion and removal uncomfortable.  TSS, although rare, is a risk associated with tampon use. Some people experience vaginal irritation from certain tampon materials.
#
# **Pads:**
#
# * **Safety:** Pads are generally considered very safe.  Change your pad regularly (every 4-8 hours or when saturated) to maintain hygiene and prevent skin irritation.
# * **Pros:** Pads are easy to use and don't require insertion.  They can be a good option for people who are new to menstruation or uncomfortable with tampons.  There is no risk of TSS with pad use.
# * **Cons:**  Pads can be less discreet and may feel bulky. They can't be worn while swimming. Some people experience skin irritation or chafing from pads.
#
# **Key Takeaway:**  The best choice for you depends on your individual needs and preferences. If you're considering using tampons for the first time, carefully read the instructions included in the package.  If you have any concerns about your menstrual health or experience unusual symptoms, consult a healthcare professional.
#
# Chatbot: There are several reasons why someone might miss a period, also known as amenorrhea.  These reasons can range from natural physiological changes to underlying medical conditions.  It's important to remember that everyone's body is different and menstrual cycles can vary.
#
# **Common Reasons for a Missed Period:**
#
# * **Pregnancy:** This is often the first thing people think of, and a pregnancy test is a good first step if you've missed a period and are sexually active.
# * **Breastfeeding:**  Hormonal changes during breastfeeding can often suppress ovulation and menstruation.
# * **Stress:**  High levels of stress can disrupt the hormonal balance needed for regular periods.
# * **Sudden Weight Loss or Gain:**  Significant changes in body weight, whether loss or gain, can affect hormone production and lead to missed periods.
# * **Excessive Exercise:**  Intense physical activity can also disrupt hormone levels and menstrual cycles.
# * **Certain Medications:**  Some medications, such as birth control pills, antidepressants, antipsychotics, and chemotherapy drugs, can cause missed periods.
# * **Medical Conditions:**  Polycystic ovary syndrome (PCOS), thyroid problems, premature ovarian insufficiency, and some other health conditions can affect menstruation.
# * **Eating Disorders:** Conditions like anorexia nervosa and bulimia can disrupt hormone production and lead to missed periods.
# * **Changes in Routine or Environment:**  Travel, jet lag, or significant changes in sleep patterns can temporarily affect the menstrual cycle.
# * **Perimenopause/Menopause:**  As women approach menopause, their periods may become irregular and eventually stop altogether. This is a natural part of aging.
#
# **When to Seek Medical Advice:**
#
# * You've missed three or more periods in a row and you're not pregnant.
# * You're experiencing other symptoms alongside the missed period, such as severe abdominal pain, unusual vaginal discharge, or fever.
# * You're concerned about the possibility of pregnancy or a medical condition.
#
# It's important to consult a healthcare professional if you have concerns about your menstrual cycle. They can help determine the cause of missed periods and recommend appropriate management or treatment.  Self-treating is not recommended, and it's always best to seek personalized medical advice.
# Goodbye! Take care of your health.
#
# Meal Planner
#
# Meal Plan:
# During the ovulatory phase, estrogen levels are rising, and it's a good time to focus on nutrient-rich foods that support energy levels and hormonal balance.  Here's a Chinese-inspired non-veg meal plan, peanut-free, with a nod to your momo craving, designed for the ovulatory phase:
#
#
# **Breakfast:** Steamed Fish with Ginger and Scallions + Bok Choy and Shiitake Mushroom Stir-fry
#
# *   **Steamed Fish:**  A light and digestible source of protein and omega-3 fatty acids, which can help reduce inflammation. Choose a white fish like cod or haddock. Steam it with fresh ginger and scallions for flavor and digestive support.
# *   **Bok Choy and Shiitake Mushroom Stir-fry:**  Provides fiber and antioxidants.  Lightly stir-fry bok choy and shiitake mushrooms with a small amount of sesame oil (peanut-free alternative) and a splash of tamari or coconut aminos.
#
#
# **Lunch:** Chicken and Vegetable Stir-fry with Brown Rice + Steamed Edamame
#
# *   **Chicken and Vegetable Stir-fry:**  Provides lean protein and a variety of nutrients. Stir-fry diced chicken breast with broccoli, carrots, bell peppers, and snap peas. Season with garlic, ginger, and a peanut-free stir-fry sauce (ensure it doesn’t contain hidden peanut ingredients).
# *   **Brown Rice:**  A complex carbohydrate for sustained energy and fiber.
# *   **Steamed Edamame:**  A good source of plant-based protein and fiber, which can help regulate blood sugar levels and reduce cravings.
#
#
# **Dinner:**  Homemade Chicken Momos (Peanut-Free) + Seaweed Soup
#
# *   **Homemade Chicken Momos:**  To satisfy your craving while keeping it healthy, make your own momos. Use ground chicken breast mixed with finely chopped vegetables like cabbage, carrots, and scallions. Season with ginger, garlic, and other spices (avoiding peanut-based sauces). Steam the momos for a healthier option. Use a dipping sauce made with tamari or coconut aminos, rice vinegar, ginger, and chili garlic sauce (ensure peanut-free).
# *   **Seaweed Soup:** This warming and comforting soup is rich in iodine, which supports thyroid function, and other minerals. Opt for a clear seaweed soup with added tofu for extra protein.
#
#
# **Important Notes:**
#
# *   **Hydration:** Drink plenty of water throughout the day to stay hydrated and support optimal bodily functions.
# *   **Portion Control:** Pay attention to portion sizes to avoid overeating.
# *   **Flexibility:** This is a sample meal plan, and you can adjust it based on your individual needs and preferences.  If you’re still experiencing cravings, consider incorporating a small, healthy treat like a piece of fruit or a handful of almonds (if no nut allergies).
# *   **Ingredient Check:** Always double-check ingredient lists to ensure they are peanut-free.
#
#
# This meal plan focuses on nutrient-dense foods to support your body during the ovulatory phase.  It includes lean protein, complex carbohydrates, healthy fats, and plenty of vegetables to provide sustained energy, manage cravings, and promote overall well-being. The inclusion of homemade momos addresses your specific craving while keeping the meal healthy and balanced.
